# %% [markdown]
# #Lista de exercícios de ESTRUTURA de DECISÃO
# #Fazer do 1 ao 20, o restante fica para estudos

# %% [markdown]
# ### 1.a) Faça um algoritmo que calcule e exiba o salário reajustado de um funcionário de acordo com a seguinte regra: Salário até 500, reajuste de 50%.

# %%
salario = float(input('Informe seu salário atual '))

if salario > 0 and salario <= 500 : 
    salarioReajustado = salario * 1.5
    print(f'Seu salário está elegível para o reajuste, e terá um novo valor de {salarioReajustado:.2f}')
else : 
    salarioReajustado = salario
    print(f'Seu salário não está elegível para o reajuste, permanecendo no valor de {salarioReajustado:.2f}')
# Out:
# Informe seu salário atual 500
# Seu salário está elegível para o reajuste, e terá um novo valor de 750.00

# %% [markdown]
# ###1.b) Faça um algoritmo que calcule e exiba o salário reajustado de um funcionário de acordo com a seguinte regra: Salário até 500, reajuste de 50%; Salários maiores que 500, reajuste de 30%.

# %%
salario = float(input('Informe seu salário atual '))

if salario > 0 and salario <= 500 : 
    salarioReajustado = salario * 1.5
    print(f'Seu salário receberá um aumento de 50%, sendo reajustado para o valor de {salarioReajustado:.2f}')
else: 
    salarioReajustado = salario * 1.3
    print(f"Seu salário receberá um aumento de 30%, sendo reajustado para o valor de {salarioReajustado:.2f}")
# Out:
# Informe seu salário atual 1000
# Seu salário receberá um aumento de 30%, sendo reajustado para o valor de 1300.00

# %% [markdown]
# ###1.c) Faça um algoritmo que calcule e exiba o salário reajustado de um funcionário de acordo com a seguinte regra: Salário até 500, reajuste de 50%; Salários maiores que 500 e até 1000, reajuste de 30%; Salários acima de 1000, reajuste de 10%.

# %%
salario = float(input('Informe seu salário atual '))

if salario > 0 and salario <= 500 :
    salarioReajustado = salario * 1.5
    print(f'Seu salário receberá um aumento de 50%, sendo reajustado para o valor de {salarioReajustado:.2f}')
elif salario > 500 and salario <= 1000 :
    salarioReajustado = salario * 1.3
    print(f'Seu salário receberá um aumento de 30%, sendo reajustado para o valor de {salarioReajustado:.2f}')
else :
    salarioReajustado = salario * 1.1
    print(f'Seu salário receberá um aumento de 10%, sendo reajustado para o valor de {salarioReajustado:.2f}')
# Out:
# Informe seu salário atual 1100
# Seu salário receberá um aumento de 10%, sendo reajustado para o valor de 1210.00

# %% [markdown]
# ###2. Faça um algoritmo que leia o nome e a idade de uma pessoa, verifique se a idade de uma pessoa é menor ou maior de idade. Considera-se maior de idade uma pessoa com 18 anos ou mais. Como saída o algoritmo deve informar o nome e a idade da pessoa e depois uma mensagem se ela é ou não maior de idade.

# %%
nome = str(input('Informe o seu nome '))
idade = int(input('Informe sua idade '))

if idade >= 18 :
    print(f'Você, {nome}, é maior de idade, já que possui {idade}')
else :
    print(f'Você, {nome}, não é maior de idade, já que possui {idade}')
# Out:
# Informe o seu nome lívia
# Informe sua idade15
# Você, lívia, não é maior de idade, já que possui 15

# %% [markdown]
# ###3.a) Faça um algoritmo que leia duas notas de um aluno, calcule a média e verifique, apresentando, se está aprovado ou reprovado.

# %%
primeiraNota = float(input('Informe a primeira nota '))
segundaNota = float(input('Informe a segunda nota '))

media = (primeiraNota + segundaNota) / 2

if media >= 6 :
    print('Parabéns! Você foi aprovado')
else : 
    print('Que pena! Você foi reprovado')
# Out:
# Informe a primeira nota 1
# Informe a segunda nota2
# Que pena! Você foi reprovado

# %% [markdown]
# ###3.b) Faça um algoritmo que calcule e apresente o que foi requerido no exercício 3.a) e também avalie a condição de aprovar/reprovar, apenas quando o aluno tem frequencia acima de 75%, este valor deve ser lido.

# %%
primeiraNota = float(input('Informe a primeira nota '))
segundaNota = float(input('Informe a segunda nota '))
frequencia = float(input('Informe a porcentagem de sua frequência '))
media = (primeiraNota + segundaNota) / 2

if media >= 6 and frequencia >= 75 :
    print('Parabéns! Você foi aprovado')
else : 
    print('Que pena! Você foi reprovado')
# Out:
# Informe a primeira nota 6
# Informe a segunda nota 6
# Informe a porcentagem de sua frequência 85
# Parabéns! Você foi aprovado

# %% [markdown]
# ###4. Faça um algoritmo que leia o gênero de uma pessoa. Se for digitado M ou F, apresentar 'Gênero válido!'. Caso contrário, 'Gênero inválido!'.

# %%
genero = str(input('Informe seu gênero '))

if genero == 'M' or genero == 'm' or genero == 'F' or genero == 'f' :
    print('Gênero válido')
else: 
    print('Gênero inválido')
# Out:
# Informe seu gênero d
# Gênero inválido

# %% [markdown]
# ###5. Tendo como dados de entrada a altura e o gênero (M/F) de uma pessoa (M-masculino ou F-feminino), construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# masculino: (72.7 * altura) - 58;
#
# feminino: (62.1 * altura) - 44.7

# %%
altura = float(input('Inforome a sua altura '))
genero = str(input('Informe seu gênero '))

if genero == 'M' or genero == 'm' :
    peso = (72.7 * altura ) - 58
    print(f'Seu peso ideal é {peso:.2f}')
elif genero == 'F' or genero == 'f' :
    peso = (62.1 * altura) - 44.7
    print(f'Seu peso ideal é {peso:.2f}')
else : 
    print(f'Gênero inválido!')
# Out:
# Inforome a sua altura 1.70
# Informe seu gênero M
# Seu peso ideal é 65.59

# %% [markdown]
# ###6. Faça um algoritmo que leia dois números inteiros e mostre o resultado da **diferença** do maior valor pelo menor.

# %%
primeiroNumero = int(input('Informe o primeiro número '))
segundoNumero = int(input('Informe o segundo número '))

if primeiroNumero > segundoNumero :
    diferenca = primeiroNumero - segundoNumero
    print(f'A diferença entre o maior valor e o menor valor é igual a {diferenca}')
elif primeiroNumero < segundoNumero :
    diferenca = segundoNumero - primeiroNumero
    print(f'A diferença entre o maior valor e o menor valor é igual a {diferenca}')
else :
    print(f'A diferença entre os dois número é nula')
# Out:
# Informe o primeiro número 5
# Informe o segundo número 5
# A diferença entre os dois número é nula

# %% [markdown]
# ###7. Uma faculdade faz o pagamento de seus professores por hora/aula. Faça um algoritmo que receba o nível e a quantidade de hora/aula, calcule e exiba o salário de um professor e a frase a seguira tabela abaixo:
# Professor Nível 1 - 11,00 reais por hora/aula, salário: ...
#
# Professor Nível 2 - 15,00 reais por hora/aula, salário: ...
#
# Professor Nível 3 - 19,00 reais por hora/aula, salário: ...

# %%
nivel = int(input('Informe o nível em que você está (1, 2 ou 3) '))
quantidade = int(input('Informe a quantidade de hora/aula que você faz '))

if nivel == 1 :
    salario = 11 * quantidade
    print(f'O salário a receber é igual a {salario:.2f}')
elif nivel == 2 :
    salario = 15 * quantidade
    print(f'O salário a receber é igual a {salario:.2f}')
elif nivel == 3 : 
    salario = 19 * quantidade
    print(f'O salário a receber é igual a {salario:.2f}')
else :
    print('Esse nível não é válido!')
# Out:
# Informe o nível em que você está (1, 2 ou 3) 3
# Informe a quantidade de hora/aula que você faz 40
# O salário a receber é igual a 760.00

# %% [markdown]
# ###8. Faça um algoritmo que leia um número inteiro e mostre uma mensagem indicando se este número é par ou ímpar e se é positivo ou negativo.

# %%
numero = int(input('Informe um número inteiro '))

if numero >= 0 and numero % 2 == 0:
    print('Esse número é positivo e par')
elif numero < 0 and numero % 2 == 0 :
    print('Esse número é negativo e par')
elif numero >= 0 and numero % 2 == 1 :
    print('Esse número é positivo e ímpar')
else :
    print('Esse número é negativo e par')
# Out:
# Informe um número inteiro -2
# Esse número é negativo e par

# %% [markdown]
# ###9. Num determinado Estado, para transferências de veículos, o DETRAN cobra uma taxa de 1% para carros fabricados antes de 1990 e uma taxa de 1.5% para os fabricados de 1990 em diante, taxa esta incidindo sobre o valor de tabela do carro. Faça um algoritmo que leia o ano e o preço do carro, calcule e apresente o imposto a ser pago.

# %%
anoFabricacao = int(input('Informe o ano de fabricação de seu carro '))
precoCarro = float(input('Informe o preço de seu carro '))

if anoFabricacao < 1990 :
    precoTaxado = (precoCarro * 1) / 100
    print(f'O imposto a ser pago equivale a R$ {precoTaxado:.2f}')
else : 
    precoTaxado = (precoCarro * 1.5) / 100
    print(f'O imposto a ser pago equivale a R$ {precoTaxado:.2f}')
# Out:
# Informe o ano de fabricação de seu carro 1700
# Informe o preço de seu carro 100
# O imposto a ser pago equivale a R$ 1.00

# %% [markdown]
# ###10. Elabore um algoritmo que informando a idade de um nadador o mesmo terá condições de classificar em uma das seguintes categorias:
# infantil = 5 - 10 anos;
#
# juvenil = 11-17 anos;
#
# adulto = maiores de 18 anos.

# %%
idade = int(input('Informe a idade do nadador '))

if idade >= 5 and idade <= 10 :
    print('O nadador se classifica como infantil')
elif idade >= 11 and idade <= 17 :
    print('O nadador se classifica como juvenil')
elif idade >= 18 :
    print('O nadador se classifica com adulto')
else :
    print('Com essa idade não é possível se classificar como nadador')
# Out:
# Informe a idade do nadador 22
# O nadador se classifica com adulto

# %% [markdown]
# ###11. Um banco concederá um crédito especial aos seus clientes, variável com o saldo médio no último ano. Faça um algoritmo que leia o saldo médio de um cliente e calcule o valor do crédito de acordo com a tabela a seguir. Mostre uma mensagem informando o saldo médio e o valor do crédito.
#         Saldo médio
#         * de 0 a 200 nenhum crédito
#         * de 201 a  400 20% do valor do saldo médio
#         * de 401 a  600 30% do valor do saldo médio
#         * acima de 601 40% do valor do saldo médio

# %%
saldoMedio = float(input('Informe seu saldo médio do último ano '))

if saldoMedio >= 0 and saldoMedio <= 200 :
    print('Você não receberá créditos ')
elif saldoMedio >= 201 and saldoMedio <= 400 :
    valorCredito = saldoMedio * 0.2
    print(f'O crédito a ser recebido equivale a {valorCredito:.2f}')
elif saldoMedio >= 401 and saldoMedio <= 600 :
    valorCredito = saldoMedio * 0.3
    print(f'O crédito a ser recebido equivale a {valorCredito:.2f}')
else : 
    valorCredito = saldoMedio * 0.4
    print(f'O crédito a ser recebido equivale a {valorCredito:.2f}')
# Out:
# Informe seu saldo médio do último ano 1000
# O crédito a ser recebido equivale a 400.00

# %% [markdown]
# ###12. A Organização Mundial de Saúde usa a seguinte tabela para determinar a condição de um adulto, para isso desenvolva um algoritmo para calcular o Índice de Massa Corporal (IMC) e apresenta-lo, dado pela fórmula:
#     IMC = peso / (altura)2   (o número 2 significa, elevado ao quadrado)
#
# CONDIÇÃO |  IMC em adultos |
#  ---|---
# Abaixo do peso  |	Abaixo de 18.5  |
# No peso normal	|	Entre 18.5 e 25|
# Acima do peso	|	Entre 25.1 e 30|
# Obeso		    |	Acima de 30|

# %%
peso = float(input('Informe seu peso '))
altura = float(input('Informe sua altura '))

imc = peso / (altura)**2

if imc < 18.5 :
    print('Você está abaixo do peso')
elif imc >= 18.5 and imc <= 25 :
    print('Você está no peso normal')
elif imc >= 25.1 and imc <= 30 :
    print('Você está acima do peso')
else : 
    print('Você está obeso')
# Out:
# Informe seu peso 70
# Informe sua altura 1.60
# Você está acima do peso

# %% [markdown]
# ###13. A nota final de um estudante é calculada a partir de três notas atribuídas, respectivamente, a um trabalho de laboratório, a uma avaliação semestral e a um exame final. A média das três notas mencionadas obedece aos pesos a seguir:
#
#  NOTA |  PESO |
#  ---|---
# Trabalho de laboratório  |   2   |
# Avaliação semestral      |   3   |
# Exame final              |   5   |
#
# ### Faça um programa que receba as três notas, calcule e mostre a média ponderada e o conceito que segue a tabela
#
# MÉDIA PONDERADA    | CONCEITO|
# ---|---
# 8,0 <= média <= 10  |    A
# 7,0 <= média < 8,0  |    B
# 6,0 <= média < 7,0  |    C
# 5,0 <= média < 6,0  |    D
#  0,0 <= média < 5,0  |    E
#
# media_ponderada = (nota_traballho * 2 + avaliacao_semestral * 3 + exame_final * 5) / 10

# %%
notaTrabalho = float(input('Informe a nota do trabalho de laboratório '))
notaAvaliacao = float(input('Informe a nota da avaliação semestral '))
notaExame = float(input('Informe a nota do exame final '))

mediaPonderada = (notaTrabalho*2 + notaAvaliacao*3 + notaExame*5) / 10

if mediaPonderada >= 8 and mediaPonderada <= 10 :
    print(f'A média ponderada equivale a {mediaPonderada:.2f} e o conceito é A')
elif mediaPonderada >= 7 and mediaPonderada < 8 : 
    print(f'A média ponderada equivale a {mediaPonderada:.2f} e o conceito é B')
elif mediaPonderada >= 6 and mediaPonderada < 7 : 
    print(f'A média ponderada equivale a {mediaPonderada:.2f} e o conceito é C')
elif mediaPonderada >= 5 and mediaPonderada < 6 :
    print(f'A média ponderada equivale a {mediaPonderada:.2f} e o conceito é D')
else :
    print(f'A média ponderada equivale a {mediaPonderada:.2f} e o conceio é E')
# Out:
# Informe a nota do trabalho de laboratório 0
# Informe a nota da avaliação semestral 0
# Informe a nota do exame final 0
# A média ponderada equivale a 0.00 e o conceio é E

# %% [markdown]
# ### 14. Faça um programa que receba três notas de um aluno, calcule e mostre a média aritmética e a mensagem constante na tabela a seguir. Aos alunos que ficaram para exame, calcule e mostre a nota que deverão tirar para serem aprovados, considerando que a média exigida é 6,0.
#
# MÉDIA ARITMÉTICA | MENSAGEM
#     ---|---
#     0 <= média < 3 |Reprovado
#     3 <= média < 6|Exame
#     6 <= média <= 10|Aprovado
#
# ```
# SE media >= 3 E media < 6
#     ESCREVA “Exame”
#     nota_exame = 12 - media
#     ESCREVA “Você deve tirar a nota”, nota_exame, “para ser aprovado.”

# %%
nota1 = float(input('Informe a primeira nota '))
nota2 = float(input('Informe a segunda nota '))
nota3 = float(input('Informe a terceira nota '))

mediaAritmetica = (nota1 + nota2 + nota3) / 3

if mediaAritmetica >= 0 and mediaAritmetica < 3 :
    print(f'Você foi reprovado. Sua média é igual a {mediaAritmetica:.2f}')
elif mediaAritmetica >= 3 and mediaAritmetica < 6 :
    notaExame = 12 - mediaAritmetica
    print(f'Você ficou de exame. Para ser aprovado você deve tirar a nota {notaExame:.2f}')
else :
    print(f'Você foi aprovado. Sua média foi {mediaAritmetica:.2f}')
# Out:
# Informe a primeira nota 10
# Informe a segunda nota 9
# Informe a terceira nota8
# Você foi aprovado. Sua média foi 9.00

# %% [markdown]
# ### 15. Faça um programa que receba dois números e mostre o maior.

# %%
primeiroNumero = float(input('Informe um número '))
segundoNumero = float(input('Informe outro número '))

if primeiroNumero > segundoNumero : 
    print(f'O maior número é {primeiroNumero}')
elif segundoNumero > primeiroNumero : 
    print(f'O maior número é {segundoNumero}')
else :
    print('Os dois números são iguais.')
# Out:
# Informe um número 1.1
# Informe outro número 1.2
# O maior número é 1.2

# %% [markdown]
# ### 16. Faça um programa que receba três números e mostre-os em ordem crescente. Suponha que o usuário digitará três números diferentes.
#
# ```
# SE numero1 < numero2 E numero1 < numero3
#     SE numero2 < numero3
#         ESCREVA “A ordem crescente é: “,numero1,“-”,numero2,“-”,numero3
#     SENÃO
#         ESCREVA “A ordem crescente é: “,numero1,“-”,numero3,“-”,numero2
# SE numero2 < numero1 E numero2 < numero3
#     SE numero1 < numero3
#         ESCREVA “A ordem crescente é: “,numero2,“-”,numero1,“-”,numero3
#     SENÃO
#         ESCREVA “A ordem crescente é: “,numero2,“-”,numero3,“-”,numero1
# SE numero3 < numero1 E numero3 < num2
#     SE numero1 < numero2
#         ESCREVA “A ordem crescente é: “,numero3,“-”,numero1,“-”,numero2
#     SENÃO
#         ESCREVA “A ordem crescente é: “,numero3,“-”,numero2,“-”,numero1
#   ```

# %%
numero1 = float(input('Informe um número '))
numero2 = float(input('Informe outro número '))
numero3 = float(input('Informe mais um número '))

if numero1 < numero2 and numero1 < numero3 :
    if numero2 < numero3 :
        print(f'A ordem crescente desses números é: {numero1}; {numero2}; {numero3}')
    else :
        print(f'A ordem crescente desses números é: {numero1}; {numero3}; {numero2}')

if numero2 < numero1 and numero2 < numero3 :
    if numero1 < numero3 :
        print(f'A ordem crescente é: {numero2}; {numero1}; {numero3}')
    else :
        print(f'A ordem crescente é: {numero2}; {numero3}; {numero1}')

if numero3 < numero1 and numero3 < numero2 : 
    if numero1 < numero2 :
        print(f'A ordem crescente é: {numero3}; {numero1}; {numero2}')
    else :
        print(f'A ordem crescente é: {numero3}; {numero2}; {numero1}')

if numero1 == numero2 and numero1 == numero3 :
    print('Todos os números são iguais!')
elif numero1 == numero2 :
    print(f'O número {numero1} é repetido duas vezes! O maior é {numero3}')

elif numero2 == numero3 :
    print(f'O número {numero2} é repetido duas vezes! O maior é {numero1}')

elif numero1 == numero3 :
    print(f'O número {numero1} é repetido duas vezes! O maior é {numero2}')
# Out:
# Informe um número 4
# Informe outro número 4
# Informe mais um número 12
# O número 4.0 é repetido duas vezes! O maior é 12.0

# %% [markdown]
# ### 17. Faça um programa que receba três números obrigatoriamente em ordem crescente e um quarto número que não siga essa regra. Mostre, em seguida, os quatro números em ordem decrescente. Suponha que o usuário digitará quatro números diferentes.
#
# ```code
# SE numero4 > numero3
#     ESCREVA “A ordem decrescente é: “,numero4,“-”,numero3,“-”,numero2,“-”,numero1
# SENÃO SE numero4 > numero2 E numero4 < numero3
#     ESCREVA “A ordem decrescente é: “,numero3,“-”,numero4,“-”,numero2,“-”,numero1
# SENÃO SE numero4 > numero1 E numero4 < numero2
#     ESCREVA “A ordem decrescente é: “,numero3,“-”,numero2,“-”,numero4, “-”,numero1
# SENÃO SE numero4 < numero1
#     ESCREVA “A ordem decrescente é: “,numero3,“-”,numero2,“-”,numero1,“-”,numero4
# ```

# %%
numero1 = float(input('Informe o primeiro número '))
numero2 = float(input('Informe um número maior que o primeiro '))
numero3 = float(input('Informe um número maior que os anteriores '))
numero4 = float(input('Informe um número que não siga a regra anterior '))

if numero1 < numero2 and numero2 < numero3 and numero1 < numero3 :
    if numero4 > numero3 :
        print(f'A ordem decrescente é: {numero4}; {numero3}; {numero2}; {numero1}')
    elif numero4 > numero2 and numero4 < numero3 :
        print(f'A ordem decrescente é:{numero3}; {numero4}; {numero2}; {numero1}')
    elif numero4 > numero1 and numero4 < numero2 :
        print(f'A ordem decrescente é: {numero3}; {numero2}; {numero4}; {numero1}')
    elif numero4 < numero1 :
        print(f'A ordem decrescente é: {numero3}; {numero2}; {numero1}; {numero4}')
elif numero1 == numero2 and numero2 == numero3 or numero4 == numero3:
    print('Os números não podem ser iguais!')
else :
    print('Os números não estão em ordem crescente!')
# Out:
# Informe o primeiro número 1
# Informe um número maior que o primeiro 3
# Informe um número maior que os anteriores 5
# Informe um número que não siga a regra anterior 7
# A ordem decrescente é: 7.0; 5.0; 3.0; 1.0

# %% [markdown]
# ### 18. Faça um programa que receba quatro valores: I, A, B e C. Desses valores, I é inteiro e positivo, A, B e C são reais. Escreva os números A, B e C obedecendo à tabela a seguir.
#
# *Suponha que o valor digitado para I seja sempre um valor válido, ou seja, 1, 2 ou 3, e que os números digitados sejam diferentes um do outro.*
#
#   |VALOR DE I | FORMA A ESCREVER|
#   |---|---|
#   |1                  |A, B e C em ordem crescente.|
#   |2                  |A, B e C em ordem decrescente|
#   |3                  |O maior fica entre os outros dois números.|
#
#   ```code
# SE I == 1
#     SE A<B E A<C
#         SE B<C
#             ESCREVA “A ordem crescente dos números é:”,A,” -”,B,”-”,C
#         SENÃO
#             ESCREVA “A ordem crescente dos números é:”,A,” -”,C,”-”,B
#     SE B<A E B<C
#         SE A<C
#             ESCREVA “A ordem crescente dos números é:”,B,”-”,A,”-”,C
#         SENÃO
#             ESCREVA “A ordem crescente dos números é: “,B,”-”,C,”-”,A
#     SE C<A E C<B
#         SE A<B
#             ESCREVA “A ordem crescente dos números é: “,C,”-”,A,”-”,B
#         SENÃO
#             ESCREVA “A ordem crescente dos números é: “,C,”-”,B,”-”,A
# SE I == 2
#     SE A>B E A>C
#         SE B>C
#             ESCREVA “A ordem decrescente dos números é: “,A,” -”,B,”-”,C
#         SENÃO
#             ESCREVA “A ordem decrescente dos números é: “,A,” -”,C,”-”,B
#     SE B>A E B>C
#         SE A>C
#             ESCREVA “A ordem decrescente dos números é: “,B,” -”,A,”-”,C
#         SENÃO
#             ESCREVA “A ordem decrescente dos números é: “,B,” -”,C,”-”,A
#     SE C>A E C>B
#         SE A>B
#             ESCREVA “A ordem decrescente dos números é: “,C,” -”,A,”-”,B
#         SENÃO
#             ESCREVA “A ordem decrescente dos números é: “,C,” -”,B,”-”,A
# SE I == 3
#     SE A>B E A>C
#         ESCREVA “A ordem desejada é: “,B,”-”,A,”-”,C
#     SE B>A E B>C
#         ESCREVA “A ordem desejada é: “,A,”-”,B,”-”,C
#     SE C>A E C>B
#         ESCREVA “A ordem desejada é: “,A,”-”,C,”-”,B
# ```

# %%
I = int(input('Informe o valor de I, podendo ser 1; 2 ou 3: '))
A = float(input('Informe o valor de A '))
B = float(input('Informe o valor de B '))
C = float(input('Informe o valor de C '))

if I >= 0 :
    if I == 1 :
        if A < B and A < C :
            if B < C :
                print(f'A ordem crescente dos números é: {A}; {B}; {C}')
            else :
                print(f'A ordem crescente dos números é: {A}; {C}; {B}')
        if B < A and B < C :
            if A < C :
                print(f'A ordem crescente dos números é: {B}; {A}; {C}')
            else :
                print(f'A ordem crescente dos números é: {B}; {C}; {A}')
        if C < A and C < B :
            if A < B :
                print(f'A ordem crescente dos números é: {C}; {A}; {B}')
            else : 
                print(f'A ordem crescente dos números é: {C}; {B}; {A}')
    if I == 2 :
        if A > B and A > C :
            if B > C :
                print(f'A ordem decrescente dos números é: {A}; {B}; {C}')
            else :
                print(f'A ordem decrescente dos números é: {A}; {C}; {B}')
        if B > A and B > C : 
            if A > C :
                print(f'A ordem decrescente dos números é: {B}; {A}; {C}')
            else : 
                print(f'A ordem decrescente dos números é: {B}; {C}; {A}')
        if C > A and C > B :
            if A > B : 
                print(f'A ordem decrescente dos números é {C}; {A}; {B}')
            else : 
                print(f'A ordem decrescente dos números é: {C}; {B}; {A}')
    if I == 3 :
        if A > B and A > C :
            print(f'A ordem desejada dos números é: {B}; {A}; {C}')
        if B > A and B > C :
            print(f'A ordem desejada dos números é: {A}; {B}; {C}')
        if C > A and C > B :
            print(f'A ordem desejada dos números é: {A}; {C}; {B}')
else : 
    print('O valor de I precisa ser positivo!')
# Out:
# Informe o valor de I, podendo ser 1; 2 ou 3: 2
# Informe o valor de A 7
# Informe o valor de B 5
# Informe o valor de C 9
# A ordem decrescente dos números é 9.0; 7.0; 5.0

# %% [markdown]
# ### 19. Faça um programa que mostre o menu de opções a seguir, receba a opção do usuário, número 1 para a escolha da soma, ou número 2 para a raiz quadrada, também receba os dados necessários para executar cada operação.
#
#     Menu de opções:
#     1. Somar dois números.
#     2. Raiz quadrada de um número.
#
# Observação: raiz = numero ** (1/2), ou
# import math
# raiz = math.sqrt(numero), assim como foi programado no exercício 18, da lista anterior.

# %%
opcao = int(input('Escolha uma das opções: 1) Somar dos números OU 2) Raiz quadrada de um número '))

if opcao == 1 :
    numero1 = float(input('Informe um número '))
    numero2 = float(input('Informe outro número que será somado ao primeiro '))
    print(f'A soma de {numero1} com {numero2} resulta em: {numero1 + numero2}')
elif opcao == 2 : 
    numeroRadicando = float(input('Informe o número desejado para saber sua raiz quadrada '))
    print(f'A raiz quadrada de {numeroRadicando} vale: {numeroRadicando ** (1/2)}')
else :
    print('Essa opção não é válida!')
# Out:
# Escolha uma das opções: 1) Somar dos números OU 2) Raiz quadrada de um número 2
# Informe o número desejado para saber sua raiz quadrada 4
# A raiz quadrada de 4.0 vale: 2.0

# %% [markdown]
# ### 20. Faça um programa que mostre a data e a hora do sistema nos seguintes formatos: **dia/mês/ano – mês por extenso e hora:minuto**.
#
# Observação: ***from*** carrega um módulo/biblioteca da linguagem Python e o ***import*** é usado para informar qual objeto desta biblioteca queremos importar/carregar no nosso programa
#
#     from datetime import datetime
#     #Este comando obtem a data e hora de hoje de algum país onde esta o servidor que executa nosso programa em Python.
#     #Quando eu testei, o servidor era do fuso horário de Dakar-Senegal
#     hoje = datetime.now()
#     print ('Ano atual.:',hoje.year)
#     print ('Mês.......:',hoje.month)
#     print ('Dia.......:',hoje.day)
#     print ('Hora......:',hoje.hour)
#     print ('Minuto....:',hoje.minute)
#     print ('Segundos..:',hoje.second)

# %%
from datetime import datetime, timezone, timedelta
hoje = datetime.now()


data_e_hora_atuais = datetime.now()
fuso_horario = timezone(timedelta(hours=-3))
print('UTC - Tempo Universal Coordenado:', fuso_horario)
dataHoraSP = data_e_hora_atuais.astimezone(fuso_horario)
dataHoraSPEmTexto = dataHoraSP.strftime('%d/%m/%Y %H:%M')
print('Data e horário de São Paulo:', dataHoraSPEmTexto)


print ('Ano atual.:',hoje.year)
print ('Mês.......:',hoje.month)
print ('Dia.......:',hoje.day)
print ('Hora......:',hoje.hour)
print ('Minuto....:',hoje.minute)
print ('Segundos..:',hoje.second)
if hoje.month == 1:
    print(hoje.day,'/Janeiro/',hoje.year)
if hoje.month == 2:
    print(hoje.day,'/Fevereiro/',hoje.year)
if hoje.month == 3:
    print(hoje.day,'/Março/',hoje.year)
if hoje.month == 4:
    print(hoje.day,'/Abril/',hoje.year)
if hoje.month == 5:
    print(hoje.day,'/Maio/',hoje.year)
if hoje.month == 6:
    print(hoje.day,'/Junho/',hoje.year)
if hoje.month == 7:
    print(hoje.day,'/Julho/',hoje.year)
if hoje.month == 8:
    print(hoje.day,'/Agosto/',hoje.year)
if hoje.month == 9:
    print(hoje.day,'/Setembro/',hoje.year)
if hoje.month == 10:
    print(hoje.day,'/Outubro/',hoje.year)
if hoje.month == 11:
    print(hoje.day,'/Novembro/',hoje.year)
if hoje.month == 12:
    print(hoje.day,'/Dezembro/',hoje.year)
# Out:
# UTC - Tempo Universal Coordenado: UTC-03:00
# Data e horário de São Paulo: 09/03/2023 07:48
# Ano atual.: 2023
# Mês.......: 3
# Dia.......: 9
# Hora......: 10
# Minuto....: 48
# Segundos..: 58
# 9 /Março/ 2023

# %%
# DICA-curiosidade, o trecho de código a  
# seguir, mostra como trocar o fuso 
# horário para o país que deseja
from datetime import datetime, timezone, timedelta

data_e_hora_atuais = datetime.now()
fuso_horario = timezone(timedelta(hours=-3))
print('UTC - Tempo Universal Coordenado:', fuso_horario)
data_e_hora_SP = data_e_hora_atuais.astimezone(fuso_horario)
data_e_hora_SP_em_texto = data_e_hora_SP.strftime('%d/%m/%Y %H:%M')
print('Data e horário de São Paulo:',data_e_hora_SP_em_texto)
# Out:
# UTC - Tempo Universal Coordenado: UTC-03:00
# Data e horário de São Paulo: 29/08/2022 17:25

# %% [markdown]
# ### 21. Faça um programa que determine a data cronologicamente maior entre duas datas fornecidas pelo usuário. Cada data deve ser composta por três valores inteiros, em que o primeiro representa o dia, o segundo, o mês e o terceiro, o ano.
#
#   ```code
#   SE ano1 > ano2
#       ESCREVA “A maior data é: “,dia1,”-”,mes1,”-”,ano1
#   SENÃO SE ano2>ano1
#       ESCREVA “A maior data é: “,dia2,”-”,mes2,”-”,ano2
#   SENÃO SE mes1>mes2
#       ESCREVA “A maior data é: “,dia1,”-”,mes1,”-”,ano1
#   SENÃO SE mes2>mes1
#       ESCREVA “A maior data é: “,dia2, “-”,mes2,”-”,ano2
#   SENÃO SE dia1>dia2
#       ESCREVA “A maior data é: “-”,dia1,”-”,mia1,” -”,ano1
#   SENÃO SE dia2>dia1
#       ESCREVA “A maior data é: “,dia2,” -”,mes2,”-”,ano2
#   SENÃO
#       ESCREVA “As datas são iguais!”
#   ```

# %%
primeiroDia = int(input('Insira o dia da primeira data '))
primeiroMes = int(input('Insira o mês da primeira data '))
primeiroAno = int(input('Insira o ano da primeira data '))

segundoDia = int(input('Insira o dia da segunda data '))
segundoMes = int(input('Insira o mês da segunda data '))
segundoAno = int(input('Insira o ano da segunda data '))

if primeiroAno > segundoAno :
    print('A data mais recente é ', primeiroDia, '/',primeiroMes, '/', primeiroAno)

elif segundoAno > primeiroAno : 
    print('A data mais recente é ', segundoDia, '/', segundoMes, '/', segundoAno )

elif primeiroMes > segundoMes :
    print('A data mais recente é ', primeiroDia, '/' , primeiroMes, '/', primeiroAno)

elif segundoMes > primeiroMes :
    print('A data mais recente é ', segundoDia, '/', segundoMes, '/', segundoAno )

elif primeiroDia > segundoDia :
    print('A data mais recente é ', primeiroDia, '/' , primeiroMes, '/', primeiroAno)

elif segundoDia > primeiroDia :
    print('A data mais recente é ', segundoDia, '/', segundoMes, '/', segundoAno )

else :
    print('As datas são iguais.')
# Out:
# Insira o dia da primeira data1
# Insira o mês da primeira data2
# Insira o ano da primeira data2023
# Insira o dia da segunda data1
# Insira o mês da segunda data2
# Insira o ano da segunda data2002
# A data mais recente é  1 / 2 / 2023

# %% [markdown]
# ### 22. Faça um programa que receba a hora do início de um jogo e a hora do término (cada hora é composta por duas variáveis inteiras: hora e minuto). Calcule e mostre a duração do jogo (horas e minutos), sabendo que o tempo máximo de duração do jogo é de 24 horas e que ele pode começar em um dia e terminar no dia seguinte.
#     SE min_inicial > min_f
#         minuto_final = minuto_final + 60
#         hora_final = hora_final – 1
#     SE hora_inicial > hora_final
#         hora_final = hora_final + 24
#     minuto_duracao = minuto_final - minuto_inicial
#     hora_duracao = hora_final - hora_inicial

# %%
minutoInicial = int(input('Informe o minuto de início da partida '))
horaInicial = int(input('Informe a hora inicial da partida '))

minutoFinal = int(input('Informe o minuto final da partida '))
horaFinal = int(input('Informe a hora do término da partida '))

if minutoInicial > minutoFinal :
    minutoFinal = minutoFinal + 60
    horaFinal = horaFinal - 1

if horaInicial > horaFinal :
    horaFinal = horaFinal + 24

minutoDuracao = minutoFinal - minutoInicial
horaDuracao = horaFinal - horaInicial 

print('O jogo teve uma duraçãõ de ', horaDuracao, ' horas e ', minutoDuracao, ' minutos')
# Out:
# Informe o minuto de início da partida0
# Informe a hora inicial da partida12
# Informe o minuto final da partida30
# Informe a hora do término da partida00
# O jogo teve uma duraçãõ de  12  horas e  30  minutos

# %% [markdown]
# ### 23. Faça um programa que receba o código correspondente ao cargo de um funcionário e seu salário atual e mostre o cargo, o valor do aumento e seu novo salário. Os cargos estão na tabela a seguir.
#
#   |CÓDIGO|CARGO|PERCENTUAL|
#   |---|---|---|
#   |1|Escriturário|50%|
#   |2|Secretário|35%|
#   |3|Caixa|20%|
#   |4|Gerente|10%|
#   |5|Diretor|Não tem aumento|
#
# ```code
# SE cargo == 1
#     ESCREVA “O cargo é Escriturário”
#     aumento = salario * 50 / 100
#     ESCREVA “O valor do aumento é: “, aumento
#     novo_sal = salario + aumento
#     ESCREVA “O novo salário é: “, novo_sal
# SENÃO SE cargo == 2
#     ESCREVA “O cargo é Secretário”
#     aumento = salario * 35 / 100
#     ESCREVA “O valor do aumento é: “, aumento
#     novo_sal = salario + aumento
#     ESCREVA “O novo salário é: “, novo_sal]
# SENÃO SE cargo == 3
#     ESCREVA “O cargo é Caixa”
#     aumento = salario * 20 / 100
#     ESCREVA “O valor do aumento é: “, aumento
#     novo_sal = salario + aumento
#     ESCREVA “O novo salário é: “,novo_sal
# SENÃO SE cargo == 4
#     ESCREVA “O cargo é Gerente”
#     aumento = salario * 10 / 100
#     ESCREVA “O valor do aumento é: “, aumento
#     novo_sal = salario + aumento
#     ESCREVA “O novo salário é: “, novo_sal
# SENÃO SE cargo == 5
#     ESCREVA “O cargo é Diretor”
#     aumento = salario * 0 / 100
#     ESCREVA “O valor do aumento é: “, aumento
#     novo_sal = salario + aumento
#     ESCREVA “O novo salário é: “, novo_sal
# ```

# %%
cargo = int(input('Informe o código de seu cargo '))
salarioAtual = float(input('Informe seu salário atual '))

if cargo == 1 : 
    print('Seu cargo é Escrituário')
    aumento = salarioAtual * 50/100
    print(f'O valor de seu aumento salarial é {aumento:.2f}')
    novoSalario = salarioAtual + aumento
    print(f'Seu novo salário é {novoSalario:.2f}')

elif cargo == 2 :
    print('Seu cargo é Secretário')
    aumento = salarioAtual * 35/100
    print(f'O valor de seu aumento salarial é {aumento:.2f}')
    novoSalario = salarioAtual + aumento
    print(f'Seu novo salário é {novoSalario:.2f}')

elif cargo == 3 :
    print('Seu cargo é Caixa')
    aumento = salarioAtual * 20/100
    print(f'O valor de seu aumento salarial é {aumento:.2f}')
    novoSalario = salarioAtual + aumento
    print(f'Seu novo salário é {novoSalario:.2f}')

elif cargo == 4 :
    print('Seu cargo é Gerente')
    aumento = salarioAtual * 10/100
    print(f'O valor de seu aumento salarial é {aumento:.2f}')
    novoSalario = salarioAtual + aumento
    print(f'Seu novo salário é {novoSalario:.2f}')

elif cargo == 5 :
    print('Seu salário não receberá aumento.')

else : 
    print('Esse código é inválido!')
# Out:
# Informe o código de seu cargo 6
# Informe seu salário atual100
# Esse código é inválido!

# %% [markdown]
# ### 24. Faça um programa que apresente o menu a seguir, permita ao usuário escolher a opção desejada, receba os dados necessários para executar a operação e mostre o resultado. Verifique a possibilidade de opção inválida e não se preocupe com restrições, como salário negativo.
#
#     Menu de opções
#     1. Imposto
#     2. Novo salário
#     3. Classificação
#     Digite a opção desejada:
#
# *Na opção 1: receber o salário de um funcionário, calcular e mostrar o valor do imposto usando as regras a seguir.*
#
#   |SALÁRIO|PERCENTUAL DO IMPOSTO|
#   |---|---|
#   |Menor que  500,00|5%|
#   |De  500,00 (inclusive) a  850,00 (inclusive)|10%|
#   |Acima de  850,00|15%|
#
# *Na opção 2: receber o salário de um funcionário, calcular e mostrar o valor do novo salário, usando as regras a seguir.*
#
#   |SALÁRIO|AUMENTO|
#   |---|---|
#   |Maior que  1.500,00| 25,00|
#   |De  750,01 a  1.500,00 (inclusive)| 50,00|
#   |De  450,00 (inclusive) a  750,00| 75,00|
#   |Menor que  450,00| 100,00|
#
# *Na opção 3: receber o salário de um funcionário e mostrar sua classificação usando a tabela a seguir.*
#
# |SALÁRIO|CLASSIFICAÇÃO|
# |---|---|
# |Até  700,00 (inclusive)|Mal remunerado|
# |Maiores que  700,00|Bem remunerado|

# %%
print('Menu de opções: : \n 1. Imposto \n 2. Novo salário \n 3. Classificação')
opcao = int(input('Informe a opção desejada: '))

if opcao == 1 :
    salario = float(input('Informe seu salário '))
    if salario < 500 :
        imposto = salario * 5/100
    elif salario >= 500 and salario <= 850 :
        imposto = salario * 10/100
    else: 
        imposto = salario * 15/100
    print(f'O valor do imposto a ser pago é {imposto:.2f}')

elif opcao == 2 :
    salario = float(input('Informe seu salário '))
    if salario > 1500 :
        salarioNovo = salario + 25
    elif salario >= 750.01 and salario <= 1500 : 
        salarioNovo = salario + 50
    elif salario >= 450 and salario <= 750 :
        salarioNovo = salario + 75
    else : 
        salarioNovo = salario + 100
    print(f'O valor do salário com aumento é {salarioNovo:.2f}')

elif opcao == 3 :
    salario = float(input('Informe seu salário '))
    if salario <= 700 :
        print('Sua classificação é mal remunerado')
    else : 
        print('Sua classificação é bem remunerado')

else:
    print('Essa opção não é válida!')
# Out:
# Menu de opções: :
#  1. Imposto
#  2. Novo salário
#  3. Classificação
# Informe a opção desejada: 3
# Informe seu salário 701
# Sua classificação é bem remunerado

# %% [markdown]
# ###25. Faça um programa que receba o salário inicial de um funcionário, calcule e mostre o novo salário, acrescido de bonificação e de auxílio escola.
#
# |SALÁRIO|BONIFICAÇÃO|
# |---|---|
# |Até  500,00|5% do salário|
# |Entre  500,01 e 1.200,00|12% do salário|
# |Acima de  1.200,00|Sem bonificação|
# >
# |SALÁRIO|AUXÍLIO ESCOLA|
# |---|---|
# |Até  600,00| 150,00|
# |Acima de  600,00| 100,00|
#
# novo_salario = salario + bonificacao + auxílio escola

# %%
salarioInicial = float(input('Informe seu salário atual '))

if salarioInicial <= 500 :
    bonificacao = salarioInicial * 5/100
    auxilioEscola = 150
elif salarioInicial > 500 and salarioInicial <= 600 :
    bonificacao = salarioInicial * 12/100
    auxilioEscola = 150
elif salarioInicial > 600 and salarioInicial <= 1200  :
    bonificacao = salarioInicial * 12/100
    auxilioEscola = 100
else : 
    bonificacao = 0
    auxilioEscola = 100

novoSalario = salarioInicial + bonificacao + auxilioEscola
print(f'O valor do novo salário com a bonificação de {bonificacao:.2f} reais, e com o auxílio escola de {auxilioEscola:.2f} reais, fica : {novoSalario:.2f} reais ')
# Out:
# Informe seu salário atual 600
# O valor do novo salário com a bonificação de 72.00 reais, e com o auxílio escola de 150.00 reais, fica : 822.00 reais

# %% [markdown]
# ### 26. Faça um programa que receba o valor do salário mínimo, o número de horas trabalhadas, o número de dependentes do funcionário e a quantidade de horas extras trabalhadas. Calcule e mostre o salário a receber do funcionário de acordo com as regras a seguir:
#
#   * O valor da hora trabalhada é igual a 1/5 do salário mínimo.
#   * O salário do mês é igual ao número de horas trabalhadas multiplicado pelo valor da hora trabalhada.
#   * Para cada dependente, acrescentar  32,00.
#   * Para cada hora extra trabalhada, calcular o valor da hora * trabalhada acrescida de 50%.
#   * O salário bruto é igual ao salário do mês mais o valor dos dependentes mais o valor das horas extras.
#   * Calcular o valor do impostoosto de renda retido na fonte de acordo com a tabela a seguir:
#
# |IRFF|SALÁRIO BRUTO|
# |---|---|
# |Isento|Inferior a  200,00|
# |10%|De  200,00 até 500,00|
# |20%|Superior a  500,00|
#
#   * O salário líquido é igual ao salário bruto menos IRRF.
#   * A gratificação é de acordo com a tabela a seguir:
#
# |SALÁRIO LÍQUIDO|GRATIFICAÇÃO|
# |---|---|
# |Até 350,00| 100,00|
# |Superior a  350| 50,00|
#
#   * O salário a receber do funcionário é igual ao salário líquido mais a gratificação.
#
#   ```code
#   LEIA salario_minimo, numero_horas_trabalhadas, numero_dependentes, numero_horas_extras
#
#   valor_hora = 1/5 * salario_minimo
#   salario_mes = numero_horas_trabalhadas * valor_hora
#   valor_dependentes = 32 * numero_dependentes
#   valor_hora_extra = numero_horas_extras * (valor_hora + (valor_hora * 50/100))
#   salario_bruto =salario_mes + valor_dependentes + valor_hora_extra
#
#   SE salario_bruto < 200
#         imposto = 0
#   SENÃO SE salario_bruto >= 200 E salario_bruto <= 500
#         imposto = salario_bruto * 10/100
#   SENÃO SE salario_bruto > 500
#         imposto = salario_bruto * 20/100
#   salario_liquido = salario_bruto – imposto
#   SE salario_liquido <= 350
#         gratificacao = 100
#   SENÃO
#         gratificacao = 50
#   salario_a_receber = salario_liquido + gratificacao
#
#   ESCREVA salario_a_receber
#   ```

# %%
salarioMinimo = float(input('Informe o valor do salário mínimo '))
numeroHorasTrabalhadas = float(input('Informe o número de horas trabalhadas '))
numeroDependentes = int(input('Informe o número de dependentes '))
numeroHorasExtras = float(input('Informe o número de horas extras trabalhadas '))

valorHora = 1/5 * salarioMinimo
salarioMes = numeroHorasTrabalhadas * valorHora
valorDependentes = numeroDependentes * 32
valorHoraExtra = numeroHorasExtras * (valorHora * 1.5)
salarioBruto = salarioMes + valorDependentes + valorHoraExtra

if salarioBruto < 200 :
    imposto = 0
elif salarioBruto >= 200 and salarioBruto <= 500 : 
    imposto = salarioBruto * 10/100
elif salarioBruto > 500 :
    imposto = salarioBruto * 20/100

salarioLiquido = salarioBruto - imposto

if salarioLiquido <= 350 :
    gratificacao = 100
else : 
    gratificacao = 50

salarioAReceber = salarioLiquido + gratificacao

print(f'O valor do salário a ser recebido é {salarioAReceber:.2f}')
# Out:
# Informe o valor do salário mínimo 100
# Informe o número de horas trabalhadas 1
# Informe o número de dependentes 1
# Informe o número de horas extras trabalhadas0
# O valor do salário a ser recebido é 152.00

# %% [markdown]
# ### 27 Um supermercado deseja reajustar os preços de seus produtos usando o seguinte critério: o produto poderá ter seu preço aumentado ou diminuído. Para o preço ser alterado, o produto deve preencher pelo menos um dos requisitos a seguir:
#
# |VENDA MÉDIA MENSAL|PREÇO ATUAL|% DE AUMENTO|% DE DIMINUIÇÃO|
# |---|--|---|---|
# |< 500|<  30000|10|-|
# |\>= 500 e <1200|\>=  30.00 e <  80.00|15|-|
# |\>= 1200|\>=  80.00|-|20|
#
# * Faça um programa que receba o preço atual e a venda média mensal do produto, calcule e mostre o novo preço.
#
# ```code
# LEIA preco_atual, media_mensal_vendas
#
# SE media_mensal_vendas < 500 OU preco_atual < 30
#     novo_preco = preco_atual + 10/100 * preco_atual
# SENÃO SE media_mensal_vendas >= 500 E media_mensal_vendas < 1200 OU preco_atual >= 30 E preco_atual<80
#     novo_preco = preco_atual + 15 / 100 * preco_atual
# SENÃO SE venda >= 1200 OU preco_atual >= 80
#     novo_preco = preco_atual – 20 / 100 * preco_atual
#
# ESCREVA novo_preco
# ```

# %%
precoAtual = float(input('Informe o preço atual do produto '))
mediaMensalVendas = float(input('Informe a medial mensal de vendas desse produto '))

if mediaMensalVendas < 500 or precoAtual < 30 :
    novoPreco = precoAtual * 1.1
elif mediaMensalVendas >= 500 and mediaMensalVendas < 1200 or precoAtual >= 30 and precoAtual < 80 :
    novoPreco = precoAtual * 1.15
elif mediaMensalVendas >= 1200 or precoAtual >= 80 :
    novoPreco = precoAtual - (0.2 * precoAtual)

print(f'O novo preço a ser implementado é {novoPreco:.2f}')
# Out:
# Informe o preço atual do produto 30
# Informe a medial mensal de vendas desse produto 1200
# O novo preço a ser implementado é 34.50

# %% [markdown]
# ### 28. Faça um programa para resolver equações do 2 o grau.
#
# **ax² + bx + c = 0**
#
# A variável *a* deve ser diferente de zero*
#
#   * delta = b ** 2 - 4 * a * c
#   * delta < 0.  **Não existe raiz real**
#   * delta = 0. **Existe uma raiz real**
#     * x = (-b) / (2 * a)
#   * delta > 0. **Existem duas raízes reais**
#     * x1 = -b + raiz(delta)/ (2 * a)
#     * x2 = -b  - raiz(delta)/ (2 * a)
#
# ```code
# LEIA a, b, c
# SE a = 0
#     ESCREVA “Estes valores não formam uma equação de segundo grau”
# SENÃO
#     delta = (b * b) – ( 4 * a * c)
#     SE delta < 0
#         ESCREVA “Não existe raiz real”
#     SE delta = 0
#         ESCREVA “Existe uma raiz real”
#         x1 = (– b) / (2 * a)
#         ESCREVA x1
#     SE delta > 0
#         ESCREVA “Existem duas raízes reais”
#         x1 = (– b) + raiz(delta) / (2 * a)
#         x2 = (– b) - raiz(delta) / (2 * a)
#         ESCREVA(x1, x2)
# ```

# %%
a = float(input('Informe o valor de A '))
b = float(input('Informe o valor de B '))
c = float(input('Informe o valor de C '))

if a == 0 :
    print('Estes valores não formam uma equação do segundo grau.')

else :
    delta = ( b * b ) - ( 4 * a * c)
    if delta < 0 :
        print('Não existe raiz real')

    if delta == 0 :
        x1 = ( - b ) / ( 2 * a )
        print(f'Existe uma raiz real, a qual vale {x1:.2f}')

    if delta > 0 :
        x1 = (( - b ) + (delta ** 0.5 )) / ( 2 * a)
        x2 = (( - b ) - (delta ** 0.5 )) / ( 2 * a)
        print(f'Existem duas raízes reais, as quais valem {x1:.2f} e {x2:.2f}')
# Out:
# Informe o valor de A 1
# Informe o valor de B 5
# Informe o valor de C 6
# Existem duas raízes reais, as quais valem -2.00 e -3.00

# %% [markdown]
# ### 29. Dados três valores X, Y e Z, verifique se eles podem ser os comprimentos dos lados de um triângulo e, se forem, verifique se é um triângulo equilátero, isósceles ou escaleno. Se eles não formarem um triângulo, escreva uma mensagem.
# Considere que:
# * o comprimento de cada lado de um triângulo é menor que a soma dos outros dois lados;
# * chama-se equilátero o triângulo que tem três lados iguais;
# * denomina-se isósceles o triângulo que tem o comprimento de dois lados iguais;
# * recebe o nome de escaleno o triângulo que tem os três lados diferentes.
#
# ```code
# LEIA x, y, z
# SE x < y + z E y < x + z E z < x + y
#     SE x = y E y = z
#         ESCREVA “Triângulo Equilátero”
#     SENÃO SE x = y OU x = z OU y = z
#         ESCREVA “Triângulo Isósceles”
#     SENÃO SE x ≠ y E x ≠ z E y ≠ z
#         ESCREVA “Triângulo Escaleno”
# SENÃO
#     ESCREVA “Essas medidas não formam um triângulo”
# ```

# %%
x = float(input('Informe o valor de x '))
y = float(input('Informe o valor de y '))
z = float(input('Informe o valor de z '))

if x < y + z and y < x + z and z < x + y :
    if x == y and y == z :
        print('Os valores formam um triângulo equilátero ')
    
    elif x == y or x == z or y == z :
        print('Os valores formam um triângulo isósceles ')

    elif x != y and x != z and y != z :
        print('Os valores formam um triângulo escaleno ')

else : 
    print('Com esses valores não é possível formar um triângulo ')
# Out:
# Informe o valor de x 5
# Informe o valor de y 4
# Informe o valor de z 3
# Os valores formam um triângulo escaleno

# %% [markdown]
# ### 30. Faça um programa que receba a altura e peso de uma pessoa. De acordo com a tabela a seguir, verifique e mostre a classificação dessa pessoa.
#
# |ALTURA|ATÉ 60|ENTRE 60 E 90 (INCLUSIVE)|ACIMA DE 90|
# |---|---|---|---|
# |Menores que 1,20|A|D|G|
# |De 1,20 a 1,70|B|E|H|
# |Maiores que 1,70|C|F|I|
#
# ```code
# LEIA altura, peso
# SE altura < 1.20
#     SE peso <= 60
#         ESCREVA “A”
#     SENÃO SE peso > 60 E peso <= 90
#         ESCREVA “D”
#     SENÃO SE peso > 90
#         ESCREVA “G”
# SENÃO SE altura >= 1.20 E altura <= 1.70
#     SE peso <= 60
#         ESCREVA “B”
#     SENÃO SE peso > 60 E peso <= 90
#         ESCREVA “E”
#     SENÃO SE peso > 90
#         ESCREVA “H”
# SENÃO SE altura > 1.70
#     SE peso <= 60
#         ESCREVA “C”
#     SENÃO SE peso > 60 E peso <= 90
#         EESCREVA “F”
#     SENÃO SE peso > 90
#         ESCREVA “I”
# ```

# %%
altura = float(input('Informe sua altura '))
peso = float(input('Informe seu peso '))

if altura < 1.20 :
    if peso <= 60 :
        print('Classificação A')
    elif peso > 60 and peso <= 90 :
        print('Classificação D')
    elif peso > 90 :
        print('Classificação G')

elif altura >= 1.20 and altura <= 1.70 :
    if peso <= 60 :
        print('Classificação B')
    elif peso > 60 and peso <= 90 :
        print('Classificação E')
    elif peso > 90 :
        print('Classificação H')
else :
    if peso <= 60 :
        print('Classificação C')
    elif peso > 60 and peso <= 90 :
        print('Classificação F')
    elif peso > 90 :
        print('Classificação I')
# Out:
# Informe sua altura 1.80
# Informe seu peso 70
# Classificação F

# %% [markdown]
# ### 31. Faça um programa que receba:
#
# * O código de um produto comprado, supondo que a digitação do código do produto seja sempre válida, isto é, um número * inteiro entre 1 e 10.
# * O peso do produto em quilos.
# * O código do país de origem, supondo que a digitação do  código seja sempre válida, isto é, um número inteiro entre 1 e 3.
#
# |CÓDIGO DO PAÍS DE ORIGEM|IMPOSTO|
# |---|---|
# |1|0%|
# |2|15%|
# |3|25%|
#
# |CÓDIGO DO PAÍS DO PRODUTO|PREÇO POR GRAMA|
# |---|---|
# |1 a 4|10|
# |5 a 7|25|
# |8 a 10|35|
#
# Calcule e mostre:
# * o peso do produto convertido em gramas;
# * o preço total do produto comprado;
# * valor do imposto, sabendo que ele é cobrado sobre o * preço total do produto comprado e dependendo país de origem;
# * o valor total, preço total do produto mais imposto.
#
# ```code
# LEIA codigo_produto, peso_quilos, codigo_pais
# peso_em_gramas = peso_quilos * 1000
# ESCREVA peso_em_gramas
# SE codigo_produto >= 1 E codigo_produto <= 4
#    preco_por_grama = 10
# SENÃO SE codigo_produto >= 5 E codigo_produto <= 7
#    preco_por_grama = 25
# SENÃO SE codigo_produto >= 8 E codigo_produto <= 10
#    preco_por_grama = 35
# preco_total = peso_em_gramas *preco_por_grama
# ESCREVA preco_total
# SE codigo_pais = 1
#     imposto = 0
# SENÃO SE codigo_pais = 2
#     imposto = preco_total * 15/100
# SENÃO SE codigo_pais = 3
#     imposto = preco_total * 25/100
# ESCREVA imposto
# valor_total = preco_total + imposto
# ESCREVA valor_total
# ```

# %%
codigoProduto = int(input('Informe o código do produto '))
pesoQuilos = float(input('Informe o peso do produto em quilos '))
codigoPais = int(input('Informe o código do país '))

pesoGramas = pesoQuilos * 1000

print(f'O produto em gramas pesa {pesoGramas} ')

if codigoProduto >= 1 and codigoProduto <= 4 :
    precoGrama = 10 
elif codigoProduto >= 8 and codigoProduto <= 10 : 
    precoGrama = 35 
else:
    print('Esse código não é válido. ')

precoTotal = pesoGramas * precoGrama

print(f'O preço total equivale a {precoTotal:.2f}')

if codigoPais == 1 :
    imposto = 0
elif codigoPais == 2 :
    imposto = 15/100 * precoTotal 
elif codigoPais == 3 :
    imposto = 25/100 * precoTotal 
else: 
    print('Esse código não é válido')

print(f'O valor do imposto é {imposto:.2f}')

valorTotal = precoTotal + imposto

print(f'O valor total é {valorTotal:.2f}')
# Out:
# Informe o código do produto 2
# Informe o peso do produto em quilos 3
# Informe o código do país 3
# O produto em gramas pesa 3000.0
# O preço total equivale a 30000.00
# O valor do imposto é 7500.00
# O valor total é 37500.00

# %% [markdown]
# ### 32. Faça um programa que receba:
# * o código do estado de origem da carga de um caminhão, supondo que a digitação do código do estado seja sempre válida, isto é, um número inteiro entre 1 e 5;
# * o peso da carga do caminhão em toneladas;
# * o código da carga, supondo que a digitação do código seja sempre válida, isto é, um número inteiro entre 10 e 40.
#
# | CÓDIGO DO ESTADO| IMPOSTO|
# |---|---|
# |1|35%|
# |2|25%|
# |3|15%|
# |4|5%|
# |5|Isento|
# >
# CÓDIGO DA CARGA|PREÇO POR QUILO
# ---|---
# 10 a 20|100
# 21 a 30|250
# 31 a 40|400
#
# Calcule e mostre:
# * o peso da carga do caminhão convertido em quilos;
# * o preço da carga do caminhão;
# * o valor do imposto, sabendo que o imposto é cobrado sobre o preço da carga do caminhão e depende do estado de origem;
# * o valor total transportado pelo caminhão, preço da carga mais imposto.
#
# ```
# LEIA codigo_estado, peso_em_toneladas, codigo_carga
# peso_em_quilos = peso_em_toneladas * 1000
# ESCREVA peso_em_quilos
# SE codigo_carga >= 10 E codigo_carga <= 20
#     preco_da_carga = 100 * peso_em_quilos
# SENÃO SE codigo_carga >= 21 E codigo_carga <= 30
#     preco_da_carga = 250 * peso_em_quilos
# SENÃO SE codigo_carga >= 31 E codigo_carga <= 40
#     preco_da_carga = 340 * peso_em_quilos
# ESCREVA preco_da_carga
# SE codigo_estado = 1
#     imposto = 35/100 * preco_da_carga
# SENÃO SE codigo_estado = 2
#     imposto = 25/100 * preco_da_carga
# SENÃO SE codigo_estado = 3
#     imposto = 15/100 * preco_ds_carga
# SENÃO SE codigo_estado = 4
#     imposto = 5/100 * preco_da_carga
# SENÃO SE codigo_estado = 5
#     imposto = 0
# ESCREVA imposto
# valor_total = preco_da_carga + imposto
# ESCREVA valor_total
# ```

# %%
codigoEstado = int(input('Informe o código do Estado de origem da carga '))
pesoToneladas = float(input('Informe o peso da carga em toneladas '))
codigoCarga = int(input('Informe o código da carga '))

pesoQuilos = pesoToneladas * 1000
print(f'O peso da carga em quilos equivale a {pesoQuilos:.2f}')

if codigoCarga >= 10 and codigoCarga <= 20 :
    precoCarga = 100 * pesoQuilos
    print(f'O preço da carga equivale a {precoCarga:.2f}')
elif codigoCarga > 20 and codigoCarga <= 30 :
    precoCarga = 250 * pesoQuilos
    print(f'O preço da carga equivale a {precoCarga:.2f}')
elif codigoCarga > 30 and codigoCarga <=40 :
    precoCarga = 400 * pesoQuilos
    print(f'O preço da carga equivale a {precoCarga:.2f}')

if codigoEstado == 1 :
    imposto = 0.35 * precoCarga
elif codigoEstado == 2 :
    imposto = 0.25 * precoCarga
elif codigoEstado == 3 :
    imposto = 0.15 * precoCarga 
elif codigoEstado == 4 :
    imposto = 0.05 * precoCarga
elif codigoEstado == 5 :
    imposto = 0 * precoCarga

print(f'O imposto aplicado sobre o preço da carga vale R$ {imposto:.2f}')

valorTotal = precoCarga + imposto

print(f'O valor total transportado pelo caminhão equivale a R$ {valorTotal:.2f}')
# Out:
# Informe o código do Estado de origem da carga 1
# Informe o peso da carga em toneladas 1
# Informe o código da carga 1
# O peso da carga em quilos equivale a 1000.00
# O imposto aplicado sobre o preço da carga vale R$ 3.50
# O valor total transportado pelo caminhão equivale a R$ 13.50

# %% [markdown]
# ### 33. Faça um programa que receba o salário base e o tempo de serviço de um funcionário. Calcule e mostre:
# * O imposto, conforme a tabela a seguir.
#
# |SALÁRIO BASE|% SOBRE O SALÁRIO BASE|
# |---|---|
# |< 200|isento|
# |>= 250 E <= 450|3%|
# |>  450 E < 700|8%|
# |>=  700|12%|
#
# * A gratificação, de acordo com a tabela a seguir.
#
# SALÁRIO BASE R$|TEMPO DE SERVIÇO|GRATIFICAÇÃO
# ---|---|---
# Superior a 500,00|Até 3 anos|20
#  | Mais de 3 anos|30
#   --------------------------|---------|--------------
# Até 500,00|Até 3 anos|23
# |Entre 3 e 6 anos|35
# |Acima de 6 anos|33
#
# * O salário líquido, ou seja, salário base menos imposto mais gratificação.
# * A categoria, que está na tabela a seguir.
#
# ```
# LEIA salario_base, tempo
#
# SE salario_base < 200
#     imposto = 0
# SENÃO SE salario_base <= 450
#     imposto = 3/100 * salario_base
# SENÃO SE sal_base < 700
#     imposto = 8/100 * salario_base
# SENÃO
#     imposto = 12/100 * salario_base
# ESCREVA imposto
# SE salario_base > 500
#     SE tempo <= 3
#          gratificacao = 20
#     SENÃO
#         gratificacao = 30
# SENÃO
#     SE tempo <= 3
#         gratificacao = 23
#     SENÃO SE tempo < 6
#         gratificacao = 35
#     SENÃO gratificacao = 33
# ESCREVA gratificacao
# salario_liquido = salario_base – imposto + gratificacao
# ESCREVA salario_liqquido
# SE salario_liquido <= 350
#     ESCREVA “Classificação A”
# SENÃO SE salario_liqquido < 600
#     ESCREVA “Classificação B”
# SENÃO
#     ESCREVA “Classificação C”
# ```

# %%
salarioBase = float(input('Informe seu salário base '))
tempoServico = float(input('Informe seu tempo de serviço '))

if salarioBase < 200 :
    imposto = 0 
elif salarioBase <= 450 :
    imposto = salarioBase * 0.03
elif salarioBase < 700 :
    imposto = salarioBase * 0.08
else:
    imposto = 0.12 * salarioBase

print(f'O imposto a ser cobrado sobre o salário base vale R$ {imposto:.2f}')

if salarioBase > 500 :
    if tempoServico <= 3:
        gratificacao = 20
    else : 
        gratificacao = 30
if salarioBase <= 500 :
    if tempoServico < 3:
        gratificacao = 23
    elif tempoServico >= 3 and tempoServico <= 6 :
        gratificacao = 35
    else: 
        gratificacao = 33

print(f'A gratificação a ser recebida equivale a R$ {gratificacao:.2f}')

salarioLiquido = salarioBase - imposto + gratificacao

print(f'O salário líquido vale R$ {salarioLiquido:.2f}')

if salarioLiquido <= 350 :
    print('Classificação A')
elif salarioLiquido < 600 :
    print('Classificação B')
else :
    print('Classificação C')
# Out:
# Informe seu salário base 100
# Informe seu tempo de serviço 1
# O imposto a ser cobrado sobre o salário base vale R$ 0.00
# A gratificação a ser recebida equivale a R$ 23.00
# O salário líquido vale R$ 123.00
# Classificação A

# %% [markdown]
# ### 34. Faça um programa que:
# * receba o valor do salário mínimo,
# * o turno de trabalho (M — matutino; V — vespertino; ou N — noturno),
# * a categoria (O — operário; G — gerente)
# * número de horas trabalhadas no mês de um funcionário.
#
# *Suponha a digitação apenas de dados válidos e, quando houver digitação de letras, utilize maiúsculas.*
#
# **Calcule e mostre:**
#
# * O coeficiente do salário, de acordo com a tabela a seguir.
#
# TURNO DE TRABALHO|VALOR DO COEFICIENTE
# ---|---
# M - Matutino|10% do salário mínimo
# V - Vespertino|15% do salário mínimo
# N - Noturno|20% do salário mínimo
#
# * O valor do salário bruto, ou seja, o número de horas trabalhadas multiplicado pelo valor do coeficiente do salário.
#
# * O imposto, de acordo com a tabela a seguir.
#
# CATEGORIA| SALÁRIO BRUTO|IMPOSTO SOBRE O SALÁRIO BRUTO
# ---|---|---
# O - Operário|>= 300,00|5%
# O - Operário|< 300,00|3%
# G - Gerente|>= 300,00|6%
# G - Gerente|< 300,00|4%
#
# * A gratificação, de acordo com as regras a seguir. Se o funcionário preencher todos os requisitos a seguir, sua gratificação será de 50,00; caso contrário, será de 30,00. Os requisitos são:
#  * Turno: Noturno
#   * Número de horas trabalhadas: Superior a 80 horas
#   * O auxílio alimentação, de acordo com as seguintes regras.
# * Auxilio alimentação, um terço do seu salário bruto; caso contrário, será de metade do seu salário bruto. Os requisitos são:
#   * Se o funcionário preencher algum dos requisitos a seguir, seu auxílio alimentação será de
#   * Categoria: Operário
#   * Coeficiente do salário: < = 25
# * O salário líquido, ou seja, salário bruto menos imposto mais gratificação mais auxílio alimentação.
# * A classificação, de acordo com a tabela a seguir:
#
# SALÁRIO LÍQUIDO|MENSAGEM
# ---|---
# Menor que 350,00|Mal remunerado
# Entre 350 e 600,00|Normal
# Maior que 600,00|Bem remunerado
#
# ```
# LEIA salario_minino, turno, categoria, numero_de_horas_trabalhadas
# SE turno = “M”
#      coeficiente = 10/100 * salario_minino
# SENÃO SE turno = “V”
#      coeficiente = 15/100 * salario_minino
# SENÃO SE turno = “N”
#      coeficiente = 12/100 * salario_minino
#
# ESCREVA coeficiente
#
# salario_bruto = numero_de_horas_trabalhadas * coeficiente
#
# ESCREVA salario_bruto
#
# SE categoria = “O”
#     SE sal_bruto >= 300
#         imposto = 5/100 * sal_bruto
#     SENÃO
#         imposto = 3/100 * sal_bruto
# SENÃO
#     SE salario_bruto >= 400
#         imposto = 6/100 * salario_bruto
#     SENÃO
#          imposto = 4/100 * salario_bruto
#
# ESCREVA imposto
#
# SE turno = “N” E numero_de_horas_trabalhadas > 80
#     gratificacao = 50
# SENÃO
#     gratificacao = 30
#
# ESCREVA gratificacao
#
# SE categoria = “O” OU coeficiente <= 25
#     auxilio = 1/3 * salario_bruto
# SENÃO
#     auxilio = 1/2 * salario_bruto
#
# ESCREVA auxilio
#
# salario_liquido = salario_bruto – imposto + gratificacao + auxilio
#
# ESCREVA salario_liquido
#
# SE salario_liquido < 350
#      ESCREVA “Mal Remunerado”
# SENÃO SE salario_liquido >= 350 E salario_liqquido <= 600
#      ESCREVA “Normal”
# SENÃO SE salario_liquido > 600
#      ESCREVA “Bem Remunerado”
# ```

# %%
salarioMinimo = float(input('Informe o valor do salário mínimo '))
turnoTrabalho = str(input('Informe o seu turno de trabalho (M - matituno; V - vespertino; ou N - noturno) '))
categoria = str(input('Informe sua categoria (O - operário ou G - gerente) '))
numeroHorasTrabalhadas = float(input('Informe o número de horas trabalhadas no mês '))

if turnoTrabalho == 'M' :
    coeficiente = salarioMinimo * 0.1
elif turnoTrabalho == 'V' :
    coeficiente = salarioMinimo * 0.15
elif turnoTrabalho == 'N' :
    coeficiente = salarioMinimo * 0.2
else:
    print('Esse turno não é válido!')

salarioBruto = numeroHorasTrabalhadas * coeficiente
print(f'O salário bruto vale R$ {salarioBruto:.2f}')

if categoria == 'O' :
    if salarioBruto >= 300 :
        imposto = salarioBruto * 0.05
    else:
        imposto = salarioBruto * 0.03

if categoria == 'G' :
    if salarioBruto >= 300 :
        imposto = salarioBruto * 0.06
    else:
        imposto = salarioBruto * 0.04

print(f'O imposto sobre o salário bruto vale R$ {imposto:.2f}')

if categoria == 'O' or coeficiente <= 25 :
    auxilioAlimentacao = 1/3 * salarioBruto
else :
    auxilioAlimentacao = 1/2 * salarioBruto 

if turnoTrabalho == 'N' and numeroHorasTrabalhadas > 80 :
    gratificacao = 50
else:
    gratificacao = 30

salarioLiquido = salarioBruto - imposto + gratificacao + auxilioAlimentacao

if salarioLiquido < 350 :
    print('Mal remunerado')
elif salarioLiquido >= 350 and salarioLiquido <= 600 :
    print('Normal')
else :
    print('Bem remunerado')
# Out:
# Informe o valor do salário mínimo 100
# Informe o seu turno de trabalho (M - matituno; V - vespertino; ou N - noturno) M
# Informe sua categoria (O - operário ou G - gerente) O
# Informe o número de horas trabalhadas no mês 10
# O salário bruto vale R$ 100.00
# O imposto sobre o salário bruto vale R$ 3.00
# Mal remunerado

# %% [markdown]
# ### 35. Faça um programa que receba de um produto:
# * o preço
# * o tipo (A — alimentação; L — limpeza; e V — vestuário)
# * a refrigeração (S — produto que necessita de refrigeração; e N — produto que não necessita de refrigeração) .
#
# **Suponha que haverá apenas a digitação de dados válidos e, quando houver digitação de letras, utilize maiúsculas. Calcule e mostre:**
#
# * O valor adicional, de acordo com a tabela a seguir:
#
# REFRIGERAÇÃO|TIPO|PREÇO|VALOR ADICIONAL
# ---|---|---|---
# N|A|<  15,00|2,00|
#  | |>= 15,00|5,00|
#  |---------|--------------|-------------------------------
#  |L|< 10,00|1,50
#  | |>= 10,00|2,50
#   |---------|--------------|-------------------------------
#  |V|< 30,00|3,00
#  ||>= 30,00|2,50
#   --------------------------|---------|--------------|-------------------------------
# S|A||8,00
# |L||0,00
# |V||0,00
#
# * O valor do imposto, de acordo com a regra a seguir.
#
# PREÇO|PERCENTUAL SOBRE O PREÇO
# ---|---
# < 25,00|5%
# >= 25,00|8%
#
# O preço de custo, ou seja, preço mais imposto.
# O desconto, de acordo com a regra a seguir.
#
# O produto que não preencher nenhum dos requisitos a seguir terá desconto de 3%, caso contrário, 0 (zero). Os requisitos são:
# * Tipo: A
# * Refrigeração: S
#
# * O novo preço, ou seja, preço de custo mais adicional menos desconto.
# * A classificação, de acordo com a regra a seguir.
#
# NOVO PREÇO|CLASSIFICAÇÃO
# ---|---
# <= 50,00|Barato
# Entre 50,01 e 100,00|Normal
# >= 100,00|Caro
#
#
# ```
# LEIA pre, tipo, refrig
# SE refrig = “N”
#     SE tipo = “A”
#         SE pre < 15
#            valor_adic = 2
#         SENÃO
#            valor_adic = 5
#     SE tipo = “L”
#         SE pre < 10
#            valor_adic = 1.5
#         SENÃO
#            valor_adic = 2.5
#     SE tipo = “V”
#         SE pre < 30
#            valor_adic = 3
#         SENÃO
#            valor_adic = 2.5
# SENÃO SE tipo = “A”
#     valor_adic = 8
#     SE tipo = “L”
#         valor_adic = 0
#     SE tipo = “V”
#         valor_adic = 0
# ESCREVA valor_adic
# SE pre < 25
#     imposto = 5/100 * pré
# SENÃO
#     imposto = 8/100 * pre
# ESCREVA imposto
# pre_custo = pre + imposto
# ESCREVA pre_custo
# SE tipo != “A” E refrig != “S”
#   desconto = 3/100 * pre_custo
# SENÃO
#   desconto = 0
# ESCREVA desconto
# novo_pre = pre_custo + valor_adic – desconto
# ESCREVA novo_pre
# SE novo_pre <= 50
#     ESCREVA “Barato”
# SENÃO SE novo_pre < 100
#     ESCREVA “Normal”
# SENÃO
#     ESCREVA “Caro”

# %%
preco = float(input('Informe o preço do produto '))
tipo = str(input('Informe o tipo do produto (A — alimentação; L — limpeza; e V — vestuário) '))
refrigeracao = str(input('Informe se o produto precisa de refrigeração ( S — produto que necessita de refrigeração; e N — produto que não necessita de refrigeração)'))

if refrigeracao == 'N' :
    if tipo == 'A' :
        if preco < 15 :
            valorAdicional = 2
        elif preco >= 15 :
            valorAdicional = 5
    elif tipo == 'L' :
        if preco < 10 :
            valorAdicional = 1.50
        elif preco >= 10 :
            valorAdicional = 2.50
    elif tipo == 'V' :
        if preco < 30 :
            valorAdicional = 3
        elif preco >= 30 :
            valorAdicional = 2.50
elif refrigeracao == 'S' :
    if tipo == 'A' :
        valorAdicional = 8
    elif tipo == 'L' :
        valorAdicional = 0
    elif tipo == 'V' :
        valorAdicional = 0

print(f'O valor adicional equivale a R$ {valorAdicional:.2f}')

if preco < 25 :
    imposto = preco * 0.05
else :
    imposto = preco * 0.08

print(f'O valor do imposto é R$ {imposto:.2f}')

precoCusto = preco + imposto 

if tipo == 'A' or refrigeracao == 'S' :
    desconto = 0
else : 
    desconto = 0.03 * precoCusto

novoPreco = precoCusto + valorAdicional - desconto

if novoPreco <= 50 :
    print('Barato')
elif novoPreco > 50 and novoPreco < 100 :
    print('Normal')
else :
    print('Caro')
# Out:
# Informe o preço do produto 100
# Informe o tipo do produto (A — alimentação; L — limpeza; e V — vestuário) A
# Informe se o produto precisa de refrigeração ( S — produto que necessita de refrigeração; e N — produto que não necessita de refrigeração)N
# O valor adicional equivale a R$ 5.00
# O valor do imposto é R$ 8.00
# Caro

# %% [markdown]
# ### 36. Faça um programa que receba a medida de um ângulo em graus. Calcule e mostre o quadrante em que se localiza esse ângulo. Considere os quadrantes da trigonometria e, para ângulos maiores que 360° ou menores que −360°, reduzí-los, mostrando também o número de voltas e o sentido da volta (horário ou anti-horário).
# ```
# SE angulo > 360 OU angulo < -360
#     voltas = parte inteira(angulo / 360)
#     angulo = RESTO(angulo / 360)
# SENÃO
#     voltas = 0
# SE angulo = 0 OU angulo = 90 OU angulo = 180
#            OU angulo = 270 OU angulo = 360
#            OU angulo = -90 OU angulo = -180
#            OU angulo = -270 OU angulo = -360
#   ESCREVA “Está em cima de algum dos eixos”
#   SE (angulo > 0 E angulo < 90) OU (angulo < -270 E angulo > -360)
#     ESCREVA “1o Quadrante”
#   SENÃO SE (angulo > 90 E angulo < 180) OU (angulo < -180 E angulo > -270)
#     ESCREVA “2o Quadrante”
#   SENÃO SE (angulo > 180 E angulo < 270) OU (angulo < -90 E angulo > -180)
#     ESCREVA “3o Quadrante”
#   SENÃO SE (angulo > 270 E angulo < 360) OU (angulo < 0 E angulo > -90)
#     ESCREVA “4o Quadrante”
#   ESCREVA voltas, “ volta(s) no sentido “
# SE angulo < 0
#     ESCREVA “horário”
# SENÃO
#     ESCREVA “anti-horário”
# ```

# %%
angulo = float(input('Informe a medida do ângulo em graus '))

if angulo > 360 or angulo < -360 :
    voltas = angulo // 360
    angulo = angulo % 360
else :
    voltas = 0

if angulo == 0 or angulo == 90 or angulo == 180 or angulo == 270 or angulo == 360 or angulo == -90 or angulo == -180 or angulo == -270 or angulo == -360 :
    print('Está em cima de algum dos eixos') 

if (angulo > 0 and angulo < 90 ) or (angulo < -270 and angulo > -360) :
    print('Primeiro quadrante')
elif (angulo > 90 and angulo < 180 ) or (angulo < -180 and angulo > -270) :
    print('Segundo quadrante')
elif (angulo > 180 and angulo < 270 ) or (angulo < -90 and angulo > -180) :
    print('Terceiro quadrante')
elif (angulo > 270 and angulo < 360 ) or (angulo < 0 and angulo > -90) :
    print('Quarto quadrante')

print(f'Foram dadas {voltas} voltas no sentido:')
if angulo < 0 :
    print('Horário')
else :
    print('Anti-horário')
# Out:
# Informe a medida do ângulo em graus 560
# Terceiro quadrante
# Foram dadas 1.0 voltas no sentido:
# Anti-horário
