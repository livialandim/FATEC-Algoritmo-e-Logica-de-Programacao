# %% [markdown]
# ### **EXERCÍCIOS DE ESTRUTURA DE REPETIÇÃO SEM CONTADOR**

# %% [markdown]
# ###1. Construir um algoritmo para calcular e apresentar o total de salários pagos de funcionários, mas não é informado a quantidade de pessoas, então use como critério de parada (condição da estrutura de repetição, digitar zero no salário para sair.

# %%
salario = 1
totalSalarios = 0

while salario > 0 :
    salario = float(input('Para encerrar o contador, digite zero. Informe o salário: '))
    if salario >= 0 :
        totalSalarios = totalSalarios + salario
    else : 
        print('Não é possível cadastrar salários negativos.')
    
print(f'O total de salários é {totalSalarios:.2f}')
# Out:
# Para encerrar o contador, digite zero. Informe o salário: 1000
# Para encerrar o contador, digite zero. Informe o salário: 500
# Para encerrar o contador, digite zero. Informe o salário: 200
# Para encerrar o contador, digite zero. Informe o salário: -20
# Não é possível cadastrar salários negativos.
# O total de salários é 1700.00

# %% [markdown]
# ###2. Faça um programa que receba a altura de 5 pessoas. Encontre e apresente a altura da pessoa mais alta e da mais baixa e seus respectivos nomes.

# %%
altura = float(input('Informe a altura: '))
pessoas = 0

while pessoas <= 5:
    nome = input('Informe o nome: ')

    if pessoas == 0 :
        maisAlto = altura
        nomeMaisAlto = nome
        maisBaixo = altura
        nomeMaisBaixo = nome
    if altura >= maisAlto :
        maisAlto = altura
        nomeMaisAlto = nome
    elif altura <= maisBaixo :
        maisBaixo = altura
        nomeMaisBaixo = nome
    altura = float(input('Informe a altura: '))

print(f'A pessoa mais alta é {nomeMaisAlto}, medindo {maisAlto:.2f}; e a mais baixa é {nomeMaisBaixo}, medindo {maisBaixo:.2f}')
# Out:
# Informe a altura: 1.6
# Informe o nome: livia
# Informe a altura: 1.8
# Informe o nome: joao
# Informe a altura: 2
# Informe o nome: marina
# Informe a altura: 1.7
# Informe o nome: gabriel
# Informe a altura: 2
# Informe o nome: igor
# Informe a altura: 1.9
# Informe o nome: diogo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-2a81f9e3e4ff> in <cell line: 4>()
#      16         maisBaixo = altura
#      17         nomeMaisBaixo = nome
# ---> 18     altura = float(input('Informe a altura: '))
#      19
#      20 print(f'A pessoa mais alta é {nomeMaisAlto}, medindo {maisAlto:.2f}; e a mais baixa é {nomeMaisBaixo}, medindo {maisBaixo:.2f}')
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# ...

# %%
for pessoas in range(5):
    altura = float(input('Informe a altura: '))
    nome = input('Informe o nome: ')
    # dica de implementação, inicializar as variáveis de menor e maior
    # valor dentro do laço de repetição, quando você souber, quantas
    # vezes repete
    if pessoas == 0:
        alto = altura
        nomea = nome
        baixo = altura
        nomeb = nome
    if altura >= alto:
        alto = altura
        nomea = nome
    elif altura <= baixo:
        baixo = altura
        nomeb = nome
print(nomea,'é mais alto, com',alto,'metros')
print(nomeb,'é mais baixo, com',baixo,'metros')
# Out:
# Informe a altura: 1.78
# Informe o nome: Lucas
# Informe a altura: 1.8
# Informe o nome: Andres
# Informe a altura: 1.75
# Informe o nome: Felipe
# Informe a altura: 1.8
# Informe o nome: Edivaldo
# Informe a altura: 1.65
# Informe o nome: Patricia
# Edivaldo é mais alto, com 1.8 metros
# Patricia é mais baixo, com 1.65 metros

# %% [markdown]
# ###3. Faça um programa que receba a altura de várias pessoas. Encontre e apresente a altura da pessoa mais alta e da mais baixa e seus respectivos nomes. Para encerrar a entrada de dados, zero na altura, mas esta não poderá ser considerada como resposta da altura da pessoa mais baixa.

# %%
altura = float(input('Informe a altura:: '))
maisAlto = altura
maisBaixo = altura
while altura > 0 :
    if altura >= maisAlto :
        maisAlto = altura
        nomeMaisAlto = input('Informe o nome: ')
    elif altura <= maisBaixo :
        maisBaixo = altura
        nomeMaisBaixo = input('Informe o nome: ')

    altura = float(input('Informe a altura: '))

print(f'A pessoa mais alta é {nomeMaisAlto}, medindo {maisAlto:.1f} metors; e a mais baixa é {nomeMaisBaixo}, medindo {maisBaixo:.1f} metros')
# Out:
# Informe a altura:: 1.7
# Informe o nome: livia
# Informe a altura: 1.8
# Informe o nome: igor
# Informe a altura: 2
# Informe o nome: joao
# Informe a altura: 1
# Informe o nome: mariina
# Informe a altura: 0
# A pessoa mais alta é joao, medindo 2.00; e a mais baixa é mariina, medindo 1.00

# %% [markdown]
# ###4. Faça um programa que receba a idade e a altura de várias pessoas. Calcule e exiba a média das alturas das pessoas com mais de 20 anos. Para encerrar a entrada de dados, digite uma idade negativa ou igual a zero.

# %%
idade = int(input('Informe a idade: '))
somaAlturas = 0
quantidadePessoas = 0
while idade > 0 :
    altura = float(input('Informe a altura: '))

    if idade > 20 :
        somaAlturas = somaAlturas + altura
        quantidadePessoas = quantidadePessoas + 1

    idade = int(input('Informe a idade: '))

if quantidadePessoas > 0:
    mediaAltura = somaAlturas / quantidadePessoas
    print(f'A média das alturas de pessoas com mais de 20 anos é {mediaAltura:2f}')
else : 
    print('Não é possível realizar uma divisão por zero ou números negativos.')
# Out:
# Informe a idade: 25
# Informe a altura: 1.8
# Informe a idade: 10
# Informe a altura: 1
# Informe a idade: 26
# Informe a altura: 1.9
# Informe a idade: 0
# A média das alturas de pessoas com mais de 20 anos é 1.850000

# %% [markdown]
# ###5. Construir um algoritmo para calcular e apresentar a idade atual de algumas pessoas em relação ao ano atual, mas não é informado a quantidade de pessoas, então use como critério de parada (condição da estrutura de repetição, digitar zero no ano de nascimento para sair.

# %%
anoAtual = int(input('Informe o ano atual: '))
anoNascimento = int(input('Informe o ano de nascimento: '))
while anoNascimento > 0 :
    idadeAtual = anoAtual - anoNascimento
    print(f'A idade atual dessa pessoa é {idadeAtual}')

    anoNascimento = int(input('Informe o ano de nascimento: '))
# Out:
# Informe o ano de nascimento: 2004
# Informe o ano atual: 2023
# A idade atual dessa pessoa é 19
# Informe o ano de nascimento: 2005
# A idade atual dessa pessoa é 18
# Informe o ano de nascimento: 0

# %% [markdown]
# ###6. Faça um programa que receba um conjunto de valores inteiros, calcule e exiba o maior e o menor valor do conjunto.
#
#
# *   Para encerrar a entrada de dados, deve ser digitado o valor zero;
# *   Para valores negativos, deve ser enviada uma mensagem;
# *   Esses valores (zero e negativos) não entrarão na lógica de encontrar o maior e o menor valor.

# %%
numero = int(input('Informe um valor inteiro: '))
maiorValor = numero
menorValor = numero
while numero > 0 or numero < 0:
    if numero > 0 :
        if numero >= maiorValor :
            maiorValor = numero
        elif numero <= menorValor :
            menorValor = numero
    else :
        print('O número mais recente é negativo.')
    
    numero = int(input('Informe um valor inteiro: '))

print(f'O maior valor é {maiorValor} e o menor valor é {menorValor}.')
# Out:
# Informe um valor inteiro: 10
# Informe um valor inteiro: -6
# O número mais recente é negativo.
# Informe um valor inteiro: 50
# Informe um valor inteiro: 1
# Informe um valor inteiro: 0
# O maior valor é 50 e o menor valor é 1.

# %% [markdown]
# ###7. No final do ano muitas pessoas compram presentes. Faça um programa que registre alguns dados das pessoas, usando como critério de parada a letra ‘n’, para a pergunta “Deseja cadastrar outro (‘s’/’n’)?”, para identificar o perfil dos compradores numa loja de roupas e apresente como resultado a:
# a)   Quantidade de mulheres e de homens;
#
# b)   Quantidade de mulheres e de homens abaixo e acima de 18 anos.

# %%
resposta = input('Deseja cadastrar outro cliente? (s/n) ')
quantidadeHomem = 0
quantidadeMaiorHomem = 0
quantidadeMenorHomem = 0 
quantidadeMulher = 0
quantidadeMaiorMulher = 0
quantidadeMenorMulher = 0

while resposta != 'n' :
    genero = input('Informe o gênero do cliente (M/F): ')

    if genero == 'M' or genero == 'm' :
        quantidadeHomem = quantidadeHomem + 1
        idadeHomem = int(input('Informe a idade do cliente: '))
        if idadeHomem >= 18:
            quantidadeMaiorHomem = quantidadeMaiorHomem + 1
        else :
            quantidadeMenorHomem = quantidadeMenorHomem + 1
    elif genero == 'F' or genero == 'f' :
        quantidadeMulher = quantidadeMulher + 1
        idadeMulher = int(input('Informe a idade da cliente: '))
        if idadeMulher >= 18 :
            quantidadeMaiorMulher = quantidadeMaiorMulher + 1
        else :
            quantidadeMenorMulher = quantidadeMenorMulher + 1
    else:
        print('Gênero inválido.')
    
    resposta = input('Deseja cadastrar outro cliente? (s/n) ')

print(f'A quantidade de mulheres é {quantidadeMulher}; e a quantidade de mulheres com idade acima de 18 anos é {quantidadeMaiorMulher} e abaixo é {quantidadeMenorMulher}')
print('-'*50)
print(f'A quantidade de homens é {quantidadeHomem}; e a quantidade de homens com idade acima de 18 anos é {quantidadeMaiorHomem} e abaixo é {quantidadeMenorHomem}')
# Out:
# Deseja cadastrar outro cliente? (s/n) s
# Informe o gênero do cliente (M/F): m
# Informe a idade do cliente: 10
# Deseja cadastrar outro cliente? (s/n) s
# Informe o gênero do cliente (M/F): m
# Informe a idade do cliente: 20
# Deseja cadastrar outro cliente? (s/n) s
# Informe o gênero do cliente (M/F): m
# Informe a idade do cliente: 18
# Deseja cadastrar outro cliente? (s/n) s
# Informe o gênero do cliente (M/F): m
# Informe a idade do cliente: 5
# Deseja cadastrar outro cliente? (s/n) s
# Informe o gênero do cliente (M/F): f
# Informe a idade da cliente: 18
# Deseja cadastrar outro cliente? (s/n) s
# Informe o gênero do cliente (M/F): f
# Informe a idade da cliente: 60
# Deseja cadastrar outro cliente? (s/n) s
# Informe o gênero do cliente (M/F): f
# Informe a idade da cliente: 12
# Deseja cadastrar outro cliente? (s/n) n
# A quantidade de mulheres é 3; e a quantidade de mulheres com idade acima de 18 anos é 2 e abaixo é 0
# --------------------------------------------------
# ...
